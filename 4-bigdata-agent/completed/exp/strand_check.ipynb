# %%
import logging
from strands import Agent
import boto3
from strands.models import BedrockModel
from strands_tools import calculator
import asyncio
from strands_tools import shell
from strand_parallel_pipe import ParallelStrand
import json
from typing import Dict, Any, Union
import sys
import io
from jinja2 import Template
import asyncio

import nest_asyncio
nest_asyncio.apply()

bedrock_model = BedrockModel(
    model_id="apac.anthropic.claude-sonnet-4-20250514-v1:0",
    region_name="ap-northeast-2",
    temperature=0.3,
)

async def main_single_query(input_text):
    try:
        agent_one = Agent(
            model=bedrock_model,
            callback_handler=None,
            system_prompt=f"""
            당신은 천문학 전문가입니다. {input_text}의 온도에 대해 말해주세요."""
        )
        
        agent_two = Agent(
            model=bedrock_model,
            callback_handler=None,
            system_prompt=f"""
            당신은 천문학 전문가입니다.  {input_text}의 구성하는 성분에 대해 말해주세요."""        
        )
        
        agent_three = Agent(
            model=bedrock_model,
            callback_handler=None,
            system_prompt=f"""
            당신은 천문학 전문가입니다.  {input_text}의 갖고있는 특성에 대해 말해주세요."""   
        )
        
        agent_dict = {
            "temperature": agent_one,
            "compose": agent_two,
            "features": agent_three
        }
        
        parallel_strand = ParallelStrand(agent_dict)
        result = await parallel_strand.invoke("system prompt의 지시를 바탕으로 실행해줘")
        return result
    except Exception as e:
        print(f"Error in main_single_query: {e}")
        import traceback
        traceback.print_exc()
        return None

# %%
result = await main_single_query("태양")

# %%
result
# Out:
# {'temperature': '안녕하세요! 천문학 전문가로서 태양의 온도에 대해 자세히 설명드리겠습니다.\n\n## 태양의 온도 구조\n\n태양은 층별로 다른 온도를 가지고 있습니다:\n\n### 1. 핵 (Core)\n- **온도**: 약 1,500만°C (1.5 × 10⁷ K)\n- 핵융합 반응이 일어나는 곳으로 가장 뜨거운 부분입니다\n\n### 2. 복사층 (Radiative Zone)\n- **온도**: 약 200만°C ~ 700만°C\n- 에너지가 복사를 통해 천천히 바깥쪽으로 전달됩니다\n\n### 3. 대류층 (Convection Zone)\n- **온도**: 약 200만°C ~ 5,800°C\n- 대류 현상을 통해 에너지가 전달됩니다\n\n### 4. 광구 (Photosphere) - 태양 표면\n- **온도**: 약 5,778K (5,505°C)\n- 우리가 보는 태양의 표면으로, 빛을 방출하는 층입니다\n\n### 5. 채층 (Chromosphere)\n- **온도**: 약 4,000°C ~ 25,000°C\n- 표면에서 멀어질수록 온도가 상승합니다\n\n### 6. 코로나 (Corona)\n- **온도**: 100만°C ~ 300만°C\n- 태양의 가장 바깥층으로 매우 뜨겁지만 밀도가 낮습니다\n\n이러한 온도 분포는 태양의 구조와 에너지 전달 메커니즘을 이해하는 데 매우 중요합니다.',
#  'compose': "태양의 구성 성분에 대해 설명드리겠습니다.\n\n## 태양의 주요 구성 성분\n\n### **수소 (Hydrogen) - 약 73%**\n- 태양 질량의 대부분을 차지하는 가장 주요한 성분\n- 핵융합 반응의 연료 역할\n- 태양 중심부에서 헬륨으로 변환되며 에너지 생성\n\n### **헬륨 (Helium) - 약 25%**\n- 두 번째로 많은 구성 성분\n- 수소 핵융합의 결과물\n- 태양의 진화 과정에서 점진적으로 증가\n\n### **기타 중원소 - 약 2%**\n천문학에서 '금속'이라 부르는 수소와 헬륨보다 무거운 원소들:\n- **산소 (O)** - 약 1%\n- **탄소 (C)** - 약 0.3%\n- **네온 (Ne)** - 약 0.2%\n- **철 (Fe)** - 약 0.2%\n- **질소, 규소, 마그네슘, 황** 등\n\n## 태양 내부 구조별 성분 분포\n\n### **핵 (Core)**\n- 수소 농도가 가장 높음\n- 활발한 핵융합으로 헬륨 비율 증가\n\n### **복사층과 대류층**\n- 상대적으로 균일한 성분 분포\n- 대류 작용으로 물질 순환\n\n### **광구 (표면)**\n- 우리가 관측하는 태양의 가시적 표면\n- 스펙트럼 분석을 통해 성분 확인 가능\n\n이러한 구성 성분들이 태양의 에너지 생산과 진화 과정을 결정하는 핵심 요소입니다.",
#  'features': '태양의 주요 특성들을 전문적으로 설명드리겠습니다.\n\n## 태양의 물리적 특성\n\n**기본 구조**\n- 질량: 약 1.989 × 10³⁰ kg (지구의 약 33만 배)\n- 반지름: 약 696,000 km (지구의 약 109배)\n- 표면온도: 약 5,778K (5,505°C)\n- 중심온도: 약 1,500만K\n\n## 핵융합과 에너지 생성\n\n태양의 핵심은 **수소 핵융합 반응**입니다:\n- 매초 약 6억 톤의 수소가 헬륨으로 변환\n- 이 과정에서 400만 톤의 질량이 에너지로 전환 (E=mc²)\n- 초당 3.8 × 10²⁶ 와트의 에너지 방출\n\n## 태양의 층구조\n\n1. **핵(Core)**: 핵융합이 일어나는 중심부\n2. **복사층**: 에너지가 복사로 전달되는 영역\n3. **대류층**: 대류 현상으로 에너지 전달\n4. **광구**: 우리가 보는 태양 표면\n5. **채층**: 광구 위의 얇은 대기층\n6. **코로나**: 최외각 대기층 (100만K 이상)\n\n## 태양 활동\n\n- **흑점**: 자기장이 강한 상대적으로 차가운 영역\n- **플레어**: 갑작스러운 에너지 폭발\n- **코로나 질량 방출**: 대량의 플라즈마 방출\n- **태양풍**: 지속적인 하전입자 흐름\n\n## 생명 주기\n\n태양은 현재 **주계열성** 단계에 있으며:\n- 나이: 약 46억 년\n- 남은 수명: 약 50억 년\n- 미래: 적색거성 → 백색왜성으로 진화 예정\n\n태양은 지구 생명체의 에너지원이자 태양계 전체를 지배하는 중력의 중심입니다.'}

# %%
def convert(template, result, role=""):
    return str(template.render(role=role, **result))

# %%
system_prompt = Template("""
당신은 천문학 전문가입니다.

{% if temperature %}
이건 대상의 온도에 관한 정보입니다:
{{ temperature }}...
{% endif %}

{% if compose %}
이건 대상의 구성에 관한 정보입니다:
{{ compose }}...
{% endif %}

{% if features %}
이건 대상의 특징에 관한 정보입니다:
{{ features }}...
{% endif %}

위의 정보를 바탕으로 다각도로 대상을 분석해주세요
""".strip()).render( **result)

# %%
system_prompt
# Out:
# "당신은 천문학 전문가입니다.\n\n\n이건 대상의 온도에 관한 정보입니다:\n안녕하세요! 천문학 전문가로서 태양의 온도에 대해 자세히 설명드리겠습니다.\n\n## 태양의 온도 구조\n\n태양은 층별로 다른 온도를 가지고 있습니다:\n\n### 1. 핵 (Core)\n- **온도**: 약 1,500만°C (1.5 × 10⁷ K)\n- 핵융합 반응이 일어나는 곳으로 가장 뜨거운 부분입니다\n\n### 2. 복사층 (Radiative Zone)\n- **온도**: 약 200만°C ~ 700만°C\n- 에너지가 복사를 통해 천천히 바깥쪽으로 전달됩니다\n\n### 3. 대류층 (Convection Zone)\n- **온도**: 약 200만°C ~ 5,800°C\n- 대류 현상을 통해 에너지가 전달됩니다\n\n### 4. 광구 (Photosphere) - 태양 표면\n- **온도**: 약 5,778K (5,505°C)\n- 우리가 보는 태양의 표면으로, 빛을 방출하는 층입니다\n\n### 5. 채층 (Chromosphere)\n- **온도**: 약 4,000°C ~ 25,000°C\n- 표면에서 멀어질수록 온도가 상승합니다\n\n### 6. 코로나 (Corona)\n- **온도**: 100만°C ~ 300만°C\n- 태양의 가장 바깥층으로 매우 뜨겁지만 밀도가 낮습니다\n\n이러한 온도 분포는 태양의 구조와 에너지 전달 메커니즘을 이해하는 데 매우 중요합니다....\n\n\n\n이건 대상의 구성에 관한 정보입니다:\n태양의 구성 성분에 대해 설명드리겠습니다.\n\n## 태양의 주요 구성 성분\n\n### **수소 (Hydrogen) - 약 73%**\n- 태양 질량의 대부분을 차지하는 가장 주요한 성분\n- 핵융합 반응의 연료 역할\n- 태양 중심부에서 헬륨으로 변환되며 에너지 생성\n\n### **헬륨 (Helium) - 약 25%**\n- 두 번째로 많은 구성 성분\n- 수소 핵융합의 결과물\n- 태양의 진화 과정에서 점진적으로 증가\n\n### **기타 중원소 - 약 2%**\n천문학에서 '금속'이라 부르는 수소와 헬륨보다 무거운 원소들:\n- **산소 (O)** - 약 1%\n- **탄소 (C)** - 약 0.3%\n- **네온 (Ne)** - 약 0.2%\n- **철 (Fe)** - 약 0.2%\n- **질소, 규소, 마그네슘, 황** 등\n\n## 태양 내부 구조별 성분 분포\n\n### **핵 (Core)**\n- 수소 농도가 가장 높음\n- 활발한 핵융합으로 헬륨 비율 증가\n\n### **복사층과 대류층**\n- 상대적으로 균일한 성분 분포\n- 대류 작용으로 물질 순환\n\n### **광구 (표면)**\n- 우리가 관측하는 태양의 가시적 표면\n- 스펙트럼 분석을 통해 성분 확인 가능\n\n이러한 구성 성분들이 태양의 에너지 생산과 진화 과정을 결정하는 핵심 요소입니다....\n\n\n\n이건 대상의 특징에 관한 정보입니다:\n태양의 주요 특성들을 전문적으로 설명드리겠습니다.\n\n## 태양의 물리적 특성\n\n**기본 구조**\n- 질량: 약 1.989 × 10³⁰ kg (지구의 약 33만 배)\n- 반지름: 약 696,000 km (지구의 약 109배)\n- 표면온도: 약 5,778K (5,505°C)\n- 중심온도: 약 1,500만K\n\n## 핵융합과 에너지 생성\n\n태양의 핵심은 **수소 핵융합 반응**입니다:\n- 매초 약 6억 톤의 수소가 헬륨으로 변환\n- 이 과정에서 400만 톤의 질량이 에너지로 전환 (E=mc²)\n- 초당 3.8 × 10²⁶ 와트의 에너지 방출\n\n## 태양의 층구조\n\n1. **핵(Core)**: 핵융합이 일어나는 중심부\n2. **복사층**: 에너지가 복사로 전달되는 영역\n3. **대류층**: 대류 현상으로 에너지 전달\n4. **광구**: 우리가 보는 태양 표면\n5. **채층**: 광구 위의 얇은 대기층\n6. **코로나**: 최외각 대기층 (100만K 이상)\n\n## 태양 활동\n\n- **흑점**: 자기장이 강한 상대적으로 차가운 영역\n- **플레어**: 갑작스러운 에너지 폭발\n- **코로나 질량 방출**: 대량의 플라즈마 방출\n- **태양풍**: 지속적인 하전입자 흐름\n\n## 생명 주기\n\n태양은 현재 **주계열성** 단계에 있으며:\n- 나이: 약 46억 년\n- 남은 수명: 약 50억 년\n- 미래: 적색거성 → 백색왜성으로 진화 예정\n\n태양은 지구 생명체의 에너지원이자 태양계 전체를 지배하는 중력의 중심입니다....\n\n\n위의 정보를 바탕으로 다각도로 대상을 분석해주세요"

# %%
agent_summary = Agent(
    model=bedrock_model,
    system_prompt=system_prompt,
    callback_handler=None
)

# %%
from IPython.display import display, HTML, clear_output
import asyncio

async def run_stream():
    output = ""
    async for event in agent_summary.stream_async("system Prompt의 지시에 따라 사용해 주세요"):
        if "data" in event:
            output += event["data"]
            clear_output(wait=True)
            display(HTML(f"<pre>{output}</pre>"))
            await asyncio.sleep(0.01)  # 화면 업데이트 시간
    print()  # 줄바꿈

# %%
await run_stream()
# Out:
# <pre># 태양에 대한 종합 분석
#
# ## 1. 온도 분석
#
# 태양의 온도 구조는 매우 흥미로운 특징을 보입니다:
#
# **핵심 발견**: 태양 표면(광구)에서 5,778K이던 온도가 코로나에서 100만K 이상으로 급격히 상승하는 **코로나 가열 문제**는 현대 천체물리학의 주요 미해결 과제 중 하나입니다.
#
# **에너지 전달 메커니즘**:
# - 핵 → 복사층: 광자의 무작위 보행으로 수십만 년 소요
# - 대류층: 플라즈마 순환으로 빠른 에너지 전달
# - 코로나 가열: 자기 재결합, 파동 가열 등 복합적 원인
#
# ## 2. 구성 성분 분석
#
# **진화적 관점**:
# - 초기 태양: 수소 ~71%, 헬륨 ~27%
# - 현재: 핵융합으로 인한 헬륨 농축 진행
# - 중원소(2%): 태양계 형성 당시 성간물질에서 상속
#
# **핵융합 효율성**:
# - pp-chain 반응이 주도적 (온도 1,500만K에서 최적)
# - CNO 사이클은 상대적으로 미미 (더 무거운 별에서 중요)
#
# ## 3. 특징 종합 분석
#
# ### 안정성의 비밀
# 태양이 46억 년간 안정적으로 에너지를 공급할 수 있는 이유:
# - **정역학적 평형**: 중력 vs 복사압
# - **열역학적 평형**: 에너지 생성 vs 방출
# - **핵연료 풍부**: 현재 핵 수소 함량으로 50억 년 더 지속 가능
#
# ### 자기장 활동
# - **11년 주기**: 태양 자기장 극성 반전
# - **나비 다이어그램**: 흑점 위도 변화 패턴
# - **지구 영향**: 오로라, 통신 장애, 기후 변화
#
# ## 4. 다각도 통합 해석
#
# ### 천체물리학적 의미
# 태양은 **G2V형 주계열성**으로서:
# - 우주에서 가장 흔한 별 유형 중 하나
# - 생명체 거주가능 영역(골디락스 존) 형성
# - 행성계 형성과 진화의 표준 모델
#
# ### 미래 전망
# **적색거성 단계 (50억 년 후)**:
# - 핵 수소 고갈 → 헬륨 연소 시작
# - 반지름 100배 확장 → 지구 궤도까지 도달
# - 질량 손실 → 행성 궤도 변화
#
# ### 연구의 최전선
# 1. **코로나 가열 메커니즘** 규명
# 2. **태양풍 가속** 과정 이해
# 3. **기후 변화**와 태양 활동 상관관계
# 4. **항성 진화 모델** 정밀화
#
# ## 결론
#
# 태양은 단순한 핵융합로가 아닌, 복잡한 자기유체역학적 시스템입니다. 온도, 구성, 활동 특성이 모두 상호 연결되어 있으며, 이를 통해 우리는 항성 물리학의 기본 원리와 태양계의 미래를 이해할 수 있습니다. 특히 코로나 가열과 같은 미해결 문제들은 향후 태양 물리학 연구의 핵심 과제로 남아있습니다.</pre>
