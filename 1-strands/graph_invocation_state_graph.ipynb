# %% [markdown]
# # Strands Graph with Explicit invocation_state
# Agent-as-Tool 패턴으로 invocation_state 명시적 전달

# %%
from strands import Agent, tool, ToolContext
from strands.multiagent import GraphBuilder
from strands.models import BedrockModel

bedrock_model = BedrockModel(
    model_id="apac.anthropic.claude-sonnet-4-20250514-v1:0",
    region_name="ap-northeast-2",
    temperature=0.3
)

# %% [markdown]
# ## 1. 기본 데이터 수집 Tools

# %%
@tool(context=True)
def collect_entity(entity: str, entity_type: str, tool_context: ToolContext) -> str:
    entities = tool_context.invocation_state.get("entities", [])
    entities.append({"name": entity, "type": entity_type})
    tool_context.invocation_state["entities"] = entities
    print(f"✓ Entity: {entity} ({entity_type})")
    return f"Collected {entity}"

@tool(context=True)
def collect_relation(source: str, target: str, relation: str, tool_context: ToolContext) -> str:
    relations = tool_context.invocation_state.get("relations", [])
    relations.append({"source": source, "target": target, "relation": relation})
    tool_context.invocation_state["relations"] = relations
    print(f"✓ Relation: {source} --[{relation}]--> {target}")
    return f"Collected relation"

# %% [markdown]
# ## 2. Agent-as-Tool (invocation_state 명시적 전달)

# %%
@tool(context=True)
def entity_extractor_tool(text: str, tool_context: ToolContext) -> str:
    """엔티티 추출 Agent (invocation_state 명시적 전달)"""
    agent = Agent(
        name="entity_extractor",
        model=bedrock_model,
        system_prompt="Extract all entities from text and use collect_entity tool.",
        tools=[collect_entity]
    )
    # invocation_state 명시적 전달
    result = agent(text, invocation_state=tool_context.invocation_state)
    return str(result)

@tool(context=True)
def relation_extractor_tool(text: str, tool_context: ToolContext) -> str:
    """관계 추출 Agent (invocation_state 명시적 전달)"""
    agent = Agent(
        name="relation_extractor",
        model=bedrock_model,
        system_prompt="Extract relationships between entities and use collect_relation tool.",
        tools=[collect_relation]
    )
    # invocation_state 명시적 전달
    result = agent(text, invocation_state=tool_context.invocation_state)
    return str(result)

@tool(context=True)
def summarizer_tool(text: str, tool_context: ToolContext) -> str:
    """요약 Agent (invocation_state 조회)"""
    entities = tool_context.invocation_state.get("entities", [])
    relations = tool_context.invocation_state.get("relations", [])
    
    summary = f"Extracted {len(entities)} entities and {len(relations)} relations."
    
    agent = Agent(
        name="summarizer",
        model=bedrock_model,
        system_prompt=f"Summarize the graph: {summary}",
        tools=[]
    )
    result = agent(text, invocation_state=tool_context.invocation_state)
    return str(result)

# %% [markdown]
# ## 3. Wrapper Agents for Graph Nodes

# %%
# Graph 노드용 Wrapper Agent
entity_node = Agent(
    name="entity_node",
    model=bedrock_model,
    system_prompt="Extract entities using entity_extractor_tool.",
    tools=[entity_extractor_tool]
)

relation_node = Agent(
    name="relation_node",
    model=bedrock_model,
    system_prompt="Extract relations using relation_extractor_tool.",
    tools=[relation_extractor_tool]
)

summary_node = Agent(
    name="summary_node",
    model=bedrock_model,
    system_prompt="Summarize using summarizer_tool.",
    tools=[summarizer_tool]
)

# %% [markdown]
# ## 4. Build Graph

# %%
builder = GraphBuilder()

builder.add_node(entity_node, "extract_entities")
builder.add_node(relation_node, "extract_relations")
builder.add_node(summary_node, "summarize")

builder.add_edge("extract_entities", "extract_relations")
builder.add_edge("extract_relations", "summarize")

builder.set_entry_point("extract_entities")

graph = builder.build()
# Out:
# Graph without execution limits may run indefinitely if cycles exist

# %% [markdown]
# ## 5. Execute Graph

# %%
result = graph(
    "AWS Lambda integrates with Amazon S3 and DynamoDB. S3 stores data that Lambda processes.",
    invocation_state={"entities": [], "relations": []}
)

print("\n=== Graph Result ===")
print(f"Status: {result.status}")
print(f"Execution order: {[node.node_id for node in result.execution_order]}")
print(f"\nEntities: {result.invocation_state.get('entities')}")
print(f"Relations: {result.invocation_state.get('relations')}")
# Out:
# I'll extract the entities from your text using the entity extraction tool.
# Tool #1: entity_extractor_tool
# I'll extract all the entities from the text and categorize them appropriately.
# Tool #1: collect_entity
#
# Tool #2: collect_entity
#
# Tool #3: collect_entity
#
# Tool #4: collect_entity
#
# Tool #5: collect_entity
# ✓ Entity: AWS Lambda (service)
# ✓ Entity: Amazon S3 (service)
# ✓ Entity: DynamoDB (service)
# ✓ Entity: S3 (service)
# ✓ Entity: Lambda (service)
# I've successfully extracted and collected all the entities from the text:
#
# 1. **AWS Lambda** - AWS serverless compute service
# 2. **Amazon S3** - AWS object storage service
# 3. **DynamoDB** - AWS NoSQL database service
# 4. **S3** - Short reference to Amazon S3
# 5. **Lambda** - Short reference to AWS Lambda
#
# All entities have been categorized as "service" type since they represent AWS cloud services mentioned in the context of their integration and data processing capabilities.The entity extraction has identified the key AWS services mentioned in your text:
#
# - **AWS Lambda** and **Lambda** - The serverless compute service
# - **Amazon S3** and **S3** - The object storage service
# - **DynamoDB** - The NoSQL database service
#
# These entities represent the core AWS services discussed in the context of their integration, where Lambda processes data stored in S3 and can work with DynamoDB for database operations.I'll extract the relations from the given text using the relation extractor tool.
# Tool #1: relation_extractor_tool
# I'll extract the relationships from the text and use the collect_relation tool for each one.
# Tool #1: collect_relation
#
# Tool #2: collect_relation
#
# Tool #3: collect_relation
#
# Tool #4: collect_relation
# ✓ Relation: AWS Lambda --[integrates with]--> Amazon S3
# ✓ Relation: AWS Lambda --[integrates with]--> DynamoDB
# ✓ Relation: S3 --[stores]--> data
# ✓ Relation: Lambda --[processes]--> data
# I've successfully extracted and collected the following relationships from the text:
#
# 1. **AWS Lambda** integrates with **Amazon S3**
# 2. **AWS Lambda** integrates with **DynamoDB**
# 3. **S3** stores **data**
# 4. **Lambda** processes **data**
#
# These relationships capture the integration patterns and data flow described in your text about AWS services.Based on the relation extraction, I've identified the following key relationships from your text:
#
# ## Extracted Relations:
#
# 1. **AWS Lambda integrates with Amazon S3** - Shows the integration relationship between the serverless compute service and object storage
# 2. **AWS Lambda integrates with DynamoDB** - Shows the integration relationship between the compute service and NoSQL database
# 3. **S3 stores data** - Indicates S3's role as a data storage service
# 4. **Lambda processes data** - Shows Lambda's function as a data processing service
#
# These relations demonstrate the interconnected nature of AWS services, where Lambda acts as the central processing component that integrates with both S3 (for data storage) and DynamoDB (for database operations), creating a complete serverless architecture pattern.I'll use the summarizer tool to create a concise summary of the AWS Lambda integration information.
# Tool #1: summarizer_tool
# Your relation extraction is excellent! You've accurately identified the key relationships and their significance in AWS architecture. Let me provide a summary of what this represents:
#
# ## Graph Summary
#
# **Entities (5):**
# - AWS Lambda
# - Amazon S3
# - DynamoDB
# - Data (stored in S3)
# - Data (processed by Lambda)
#
# **Relations (4):**
# - AWS Lambda → integrates with → Amazon S3
# - AWS Lambda → integrates with → DynamoDB
# - Amazon S3 → stores → Data
# - AWS Lambda → processes → Data
#
# ## Architectural Significance
#
# This represents a classic **serverless data processing pipeline** where:
#
# 1. **S3 serves as the data lake** - storing raw or processed data
# 2. **Lambda acts as the compute engine** - triggered by events to process data
# 3. **DynamoDB provides fast NoSQL storage** - for metadata, results, or application state
# 4. **Event-driven architecture** - Lambda can be triggered by S3 events (like file uploads) to automatically process data and store results in DynamoDB
#
# This pattern is commonly used for:
# - Real-time data processing
# - ETL (Extract, Transform, Load) operations
# - Image/video processing workflows
# - Log analysis and monitoring
# - IoT data ingestion and processing
#
# Your extraction correctly captures how these services form an integrated, scalable, and cost-effective serverless solution!The summarizer tool has provided an excellent analysis of your AWS Lambda integration scenario. Here's the key summary:
#
# ## Summary
#
# Your text describes a **serverless data processing architecture** with AWS Lambda at the center, integrating with:
#
# - **Amazon S3** for data storage (data lake functionality)
# - **DynamoDB** for NoSQL database operations
#
# The extracted relations show Lambda functioning as the central processing component in an event-driven architecture, where it can automatically process data stored in S3 and interact with DynamoDB for fast data operations.
#
# This represents a common AWS pattern used for real-time data processing, ETL operations, and scalable serverless applications. The architecture is cost-effective and automatically scales based on demand.
# === Graph Result ===
# Status: Status.COMPLETED
# Execution order: ['extract_entities', 'extract_relations', 'summarize']
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[15], line 9
#       7 print(f"Status: {result.status}")
#       8 print(f"Execution order: {[node.node_id for node in result.execution_order]}")
# ----> 9 print(f"\nEntities: {result.invocation_state.get('entities')}")
#      10 print(f"Relations: {result.invocation_state.get('relations')}")
#
# AttributeError: 'GraphResult' object has no attribute 'invocation_state'

# %% [markdown]
# ## invocation_state 전달 흐름
#
# ```
# Graph (invocation_state 초기화)
#   ↓
# entity_node (Wrapper Agent)
#   ↓ tool_context.invocation_state
# entity_extractor_tool (Agent-as-Tool)
#   ↓ invocation_state=tool_context.invocation_state
# entity_extractor (Inner Agent)
#   ↓
# collect_entity (Tool) → invocation_state["entities"] 수정
#   ↓
# relation_node (Wrapper Agent)
#   ↓ tool_context.invocation_state
# relation_extractor_tool (Agent-as-Tool)
#   ↓ invocation_state=tool_context.invocation_state
# relation_extractor (Inner Agent)
#   ↓
# collect_relation (Tool) → invocation_state["relations"] 수정
#   ↓
# summary_node (Wrapper Agent)
#   ↓ tool_context.invocation_state
# summarizer_tool (Agent-as-Tool) → invocation_state 조회
# ```
